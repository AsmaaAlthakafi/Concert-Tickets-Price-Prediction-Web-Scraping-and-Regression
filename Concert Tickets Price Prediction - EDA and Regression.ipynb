# %% [markdown]
# # Concert Tickets Price Prediction - EDA and Regression
# #### By: Sarah Alabdulwahab & Asma Althakafi
#
# >Our goal for this project is to predict the prices of the concert tickets of the upcoming concerts in America.

# %% [markdown]
# ## Data Description
# After we obtained the datasets by scraping two websites: Razorgator and Wikipedia, these are the features for the concert tickets:
# - **Artist**: A band or an individual that will perform live music.
# - **Data**, which contains the following:
#     - **City**: The city that the concert will occur in.
#     - **State**: The state that the concert will occur in.
#     - **Venue**: The venue that the concert will occur in.
#     - **Date**: The date that the concert will occur on.
#     - **Day**: The day that the concert will occur on.
#     - **Time**: The time that the concert will occur at.
# - **Level**: Front, middle, and last sections/rows.
# - **Price**: The price of the concert ticket.
#
# And these are the features for the salaries:
# - **State**: The name of the state.
# - **Median Salary**: The median salary of the corresponding state.
# - **Average Salary**: The average salary of the corresponding state.

# %%
#imports
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import pandas as pd
import numpy as np

from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt  
# %matplotlib inline

from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import (RandomForestRegressor, AdaBoostRegressor, BaggingClassifier,
                                RandomForestClassifier, AdaBoostClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression
from sklearn.model_selection import KFold, GridSearchCV

# %% [markdown]
# ## Tickets Data

# %%
#reading file
df_tickets = pd.read_csv('tickets.csv')
df_tickets
# Out:
#                    artist                                               data  \
# 0       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 1       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 2       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 3       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 4       Machine Gun Kelly  Ascend Amphitheater: Nashville, TN -\nWed, Oct...
# ...                   ...                                                ...
# 180089     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180090     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180091     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180092     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180093     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
#
#                        level price
# 0       Section GA • Row GA1  $202
# 1          VIP BALC • Row GA  $278
# 2          VIP BALC • Row GA  $291
# 3         FLOOR GA • Row GA1  $370
# 4           GA Pit • Row GA0  $394
# ...                      ...   ...
# 180089   Section 113 • Row 5  $438
# 180090   Section 302 • Row 8  $152
# 180091   Section 301 • Row 1  $209
# 180092  Section 108 • Row 11  $250
# 180093    Section C • Row 10  $418
#
# [180094 rows x 4 columns]

# %%
df_tickets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180094 entries, 0 to 180093
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   artist  180094 non-null  object
#  1   data    180094 non-null  object
#  2   level   180094 non-null  object
#  3   price   180094 non-null  object
# dtypes: object(4)
# memory usage: 5.5+ MB

# %%
#drop the dublicate rows, because it could produce inaccurate predictions
df_tickets.drop_duplicates(subset = ['artist','data','level'], keep = False, inplace = True)
df_tickets
# Out:
#                    artist                                               data  \
# 0       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 3       Machine Gun Kelly  Eagles Ballroom: Milwaukee, WI - Tue, Oct 05 2...
# 5       Machine Gun Kelly  Ascend Amphitheater: Nashville, TN -\nWed, Oct...
# 6       Machine Gun Kelly  Ascend Amphitheater: Nashville, TN -\nWed, Oct...
# 13      Machine Gun Kelly  Ascend Amphitheater: Nashville, TN -\nWed, Oct...
# ...                   ...                                                ...
# 180088     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180089     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180090     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180091     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
# 180092     Dave Chappelle  Smoothie King Center: New Orleans, LA -\nThu, ...
#
#                         level price
# 0        Section GA • Row GA1  $202
# 3          FLOOR GA • Row GA1  $370
# 5            GA Pit • Row GAO  $407
# 6            GA Pit • Row GA2  $407
# 13      Section 101 • Row ADA  $225
# ...                       ...   ...
# 180088   Section 310 • Row 14   $98
# 180089    Section 113 • Row 5  $438
# 180090    Section 302 • Row 8  $152
# 180091    Section 301 • Row 1  $209
# 180092   Section 108 • Row 11  $250
#
# [104164 rows x 4 columns]

# %% [markdown]
# ### Exploring and Cleaning the Artist Feature

# %%
df_tickets['artist'].unique()
# Out:
# array(['Machine Gun Kelly', 'Run the Jewels', 'J. Cole', '21 Savage',
#        'Post Malone', 'Doja Cat', 'Tyler The Creator', 'Travis Scott',
#        'Jack Harlow', 'Megan Thee Stallion', 'DaBaby', 'ATLiens',
#        'DJ Diesel', 'Z-Trip', 'The Martinez Brothers', 'Tsuruda',
#        'Pitbull', 'Don Toliver', 'Russ', 'Saint Jhn', 'T-Pain', '50 Cent',
#        'Ying Yang Twins', 'Lil Baby', 'Lil Durk', 'Elton John',
#        'Billie Eilish', 'Joan Jett And The Blackhearts', 'Poison',
#        'The Stadium Tour', 'Motley Crue', 'Def Leppard', 'Harry Styles',
#        'The Rolling Stones', 'Ashley McBryde', 'BTS - Bangtan Boys',
#        'Justin Bieber', 'Billy Joel', 'Dead & Company', 'Genesis',
#        'Dua Lipa', 'Celine Dion', 'James Taylor', 'Rammstein',
#        'The Eagles', 'John Mayer', 'Jackson Browne', 'Lady Gaga',
#        'Backstreet Boys', 'Luke Combs', 'Kenny Chesney', 'Drew Parker',
#        'Garth Brooks', 'Ray Fulcher', 'Chris Stapleton', 'George Strait',
#        'Kane Brown', 'Eric Church', 'Dan and Shay', 'Reba McEntire',
#        'Caitlyn Smith', 'Morgan Wallen', 'Zac Brown Band', 'Hardy',
#        'The War and Treaty', 'Luke Bryan', 'Runaway June',
#        'Little Big Town', 'Jon Pardi', 'Jason Aldean', 'Jon Langston',
#        'Lainey Wilson', 'Jenny Lewis', 'Bad Bunny', 'The Weeknd',
#        'My Chemical Romance', 'Rage Against The Machine', 'Phish',
#        'Metallica', 'Aftershock Festival', 'Sebastian Maniscalco',
#        'ATLive', 'Tool', 'CMA Music Festival', 'Andrea Bocelli',
#        'Dave Matthews', 'Dave Matthews Band', 'Jhene Aiko',
#        'The Marcus King Band', 'Austin City Limits Festival',
#        'Jimmy Buffett', 'Lauren Daigle', 'Widespread Panic',
#        'Sabrina Claudio', 'Rufus Du Sol', 'Dave Chappelle'], dtype=object)

# %%
#removing festivals
df_tickets = df_tickets[(df_tickets['artist'] != 'Aftershock Festival') & (df_tickets['artist'] != 'ATLive') & (df_tickets['artist'] != 'The Stadium Tour') & (df_tickets['artist'] != 'CMA Music Festival')]

# %%
len(df_tickets['artist'].unique())
# Out:
# 92

# %% [markdown]
# ### Exploring and Cleaning the Data Feature

# %%
#clean the data feature: extract the venue, city, state, date, and time
venues = []
cities = []
states = []
dates = []
times = []

for x in df_tickets['data']:
    # for example, x is 'Rocket Mortgage FieldHouse: Cleveland, OH -\nSat, Dec 18 2021 7:30 PM\n'
    x = x.strip().replace('\n', ' ')
    times.append(x[-8:].strip())
    
    # txt is['Rocket Mortgage FieldHouse', 'Cleveland, OH - Sat, Dec 18 2021 7', '30 PM']
    txt = x.split(':')
    venues.append(txt[0].strip())
    
    #txt[1] is 'Cleveland, OH - Sat, Dec 18 2021 7'
    #txt2 is ['Cleveland', ' OH - Sat', 'Dec 18 2021 7']
    txt2 = txt[1].split(',')
    cities.append(txt2[0].strip())
    states.append(txt2[1][:3].strip())
        
    if len(txt2) == 3:
        dates.append(txt2[2][:12].strip())
    else:
        dates.append('TBD')

# %%
#store lists to df_tickets
df_tickets['venue'] = venues
df_tickets['city'] = cities
df_tickets['state'] = states
df_tickets['date'] = dates 
df_tickets['time'] = times

# %%
#print all unique values
df_tickets['venue'].unique()
# Out:
# array(['Eagles Ballroom', 'Ascend Amphitheater',
#        'Bill Graham Civic Auditorium', 'Pavilion at Riverfront',
#        'McMenamins Historic Edgefield Amphitheater', 'Greek Theatre',
#        'The Theater at Virgin Hotels - Las Vegas',
#        'The Lot at The Complex', 'Red Rocks Amphitheatre',
#        'Shrine LA Outdoors', 'Mesa Amphitheatre', 'Mardi Gras World',
#        'Oklahoma City Zoo Amphitheatre',
#        'The Pavilion at Toyota Music Factory',
#        'Charlotte Metro Credit Union Amphitheatre at the AvidXchange Music Factory',
#        'Virginia Credit Union LIVE! at Richmond Raceway',
#        'Petersen Events Center', 'Mohegan Sun Arena',
#        'Rocket Mortgage FieldHouse', 'Don Haskins Center',
#        'Pan American Center', 'Gila River Arena', 'Oakland Arena',
#        'Tacoma Dome', 'Moda Center at the Rose Quarter',
#        'Pacific Coliseum', 'Rogers Place', 'Scotiabank Saddledome',
#        'Bell MTS Place', 'Denny Sanford Premier Center', 'Target Center',
#        'T-Mobile Center', 'Enterprise Center', 'Little Caesars Arena',
#        'Alpine Valley Music Theatre', 'United Center',
#        'FirstOntario Centre', 'Scotiabank Arena', 'KeyBank Center',
#        'PPG Paints Arena', 'PNC Arena', 'Capital One Arena',
#        'Madison Square Garden', 'Toyota Center',
#        'American Airlines Center', 'Ball Arena', 'MGM Grand Garden Arena',
#        'Footprint Center', 'The Forum - Los Angeles',
#        'Wells Fargo Center', 'Citi Field', 'Nos Events Center',
#        'Memphis Fairgrounds', 'AT&T Stadium Parking Lots',
#        'Gulf Shores Beach', 'Hollywood Bowl', 'Dickies Arena',
#        'Allstate Arena', 'TD Garden', 'State Farm Arena', 'BB&T Center',
#        'The Fillmore - Charlotte', 'Canton Hall - Dallas',
#        'Pechanga Arena', 'Mandalay Bay - Michelob ULTRA Arena',
#        'Chaifetz Arena', 'Cable Dahmer Arena', 'Fiserv Forum',
#        'Schottenstein Center', 'DCU Center',
#        'Chartway Arena at Ted Constant Convocation Center', 'Place Bell',
#        'Bojangles Coliseum', 'Amway Center', 'The Yuengling Center',
#        'FTX Arena', 'North Charleston Coliseum', 'Gas South Arena',
#        'Staples Center', 'Golden 1 Center', 'Climate Pledge Arena',
#        'NRG Park', 'The Pageant', 'Marathon Music Works',
#        'House Of Blues - New Orleans', 'House Of Blues - Houston',
#        'The Van Buren', 'McMenamins Crystal Ballroom', 'Showbox SoDo',
#        'Commodore Ballroom', 'The Depot - Salt Lake City',
#        'The Mission Ballroom', 'Byline Bank Aragon Ballroom',
#        'The Fillmore - Minneapolis', 'Water Street Music Hall', 'History',
#        'House Of Blues - Cleveland',
#        'Egyptian Room At Old National Centre', 'Iron City - Birmingham',
#        'The Observatory', 'Miller High Life Theatre',
#        'Mississippi Coast Coliseum', 'Las Vegas Motor Speedway',
#        'Starlight Theatre', 'Bridgestone Arena',
#        'PNC Music Pavilion - Charlotte', 'Ameris Bank Amphitheatre',
#        "Daily's Place Amphitheater",
#        'MidFlorida Credit Union Amphitheatre At The Florida State Fairgrounds',
#        'Rushmore Plaza - Summit Arena', 'Wind Creek Event Center',
#        'Hard Rock Live At Etess Arena', 'Fort Lauderdale Beach Park',
#        'Fantasy Springs Resort & Casino',
#        'The Pool at Talking Stick Resort', 'Laughlin Events Center',
#        'The Dome at Oakdale Theatre', 'The Fillmore - Philadelphia',
#        'Echostage', 'The Ritz', 'The Oasis Wynwood', 'Coca-Cola Roxy',
#        'Bayou Music Center', 'The Bomb Factory', 'Fillmore Auditorium',
#        'Rockwell At The Complex', 'Warfield', 'Fox Theater - Oakland',
#        'Hollywood Palladium', 'Sacramento Memorial Auditorium',
#        'Amarillo Civic Center', 'The Criterion',
#        'TCU Amphitheater At White River State Park',
#        'Wamu Theater At Lumen Field Event Center',
#        'Greek Theatre - U.C. Berkeley',
#        'Cal Coast Credit Union Open Air Theatre',
#        'Smart Financial Centre', 'HEB Center at Cedar Park',
#        'The Armory - Minneapolis',
#        'Michigan Lottery Amphitheatre at Freedom Hill', 'EXPRESS LIVE!',
#        'Radio City Music Hall', 'Leader Bank Pavilion',
#        'Echo Beach at Budweiser Stage', 'Stage AE',
#        'The Met - Philadelphia', 'MECU Pavilion',
#        'FPL Solar Amphitheater', 'The Pressroom',
#        'House Of Blues - Dallas', 'Stubbs Waller Creek Amphitheater',
#        'Jannus Live',
#        'The Fillmore Miami Beach At Jackie Gleason Theater',
#        'The Eastern', 'PromoWest Pavilion at OVATION', 'Agora Theatre',
#        'The Fillmore - Detroit', 'Rebel', 'House Of Blues - Boston',
#        'Franklin Music Hall', 'The Fillmore Silver Spring', 'Terminal 5',
#        'Riviera Theatre - IL', 'First Avenue',
#        "Cervantes' Masterpiece - Ballroom", 'Roseland Theater',
#        'House Of Blues - San Diego', 'House Of Blues - Anaheim',
#        'The Novo', 'Las Vegas Festival Grounds',
#        'Banc of California and Exposition Park', 'Royal Farms Arena',
#        'Greensboro Coliseum At Greensboro Coliseum Complex',
#        'Spectrum Center', 'Texas Trust CU Theatre at Grand Prairie',
#        'Smoothie King Center', 'UWM Panther Arena', 'Wintrust Arena',
#        'Nashville Municipal Auditorium', 'Heritage Bank Center',
#        'Amalie Arena', 'VyStar Veterans Memorial Arena',
#        'Prudential Center', 'Hampton Coliseum', 'Colonial Life Arena',
#        "Raising Cane's River Center Arena", 'FedExForum',
#        'Brewster Street Ice House', 'Mississippi Coliseum',
#        'Barclays Center', 'KFC Yum! Center',
#        'iTHINK Financial Amphitheatre', 'Simmons Bank Arena',
#        'Brookshire Grocery Arena', 'INTRUST Bank Arena',
#        'Pinnacle Bank Arena', 'Scope Arena', 'The Pavilion At Star Lake',
#        'Times Union Center', 'O2 Arena - London',
#        'Chesapeake Energy Arena', 'Centre Bell', 'Nassau Coliseum',
#        'Fargodome', 'Xcel Energy Center', 'Wells Fargo Arena',
#        'Bankers Life Fieldhouse', 'Van Andel Arena',
#        'Thompson Boling Arena', 'Rupp Arena At Central Bank Center',
#        'Giant Center', 'Hyde Park - London', 'Citizens Bank Park',
#        'Comerica Park', 'MetLife Stadium', 'Gillette Stadium',
#        'Progressive Field', 'Soldier Field Stadium', 'Rogers Centre',
#        'Carrier Dome', 'PNC Park', 'Bank Of America Stadium',
#        'Mercedes-Benz Stadium', 'Nationals Park', 'Globe Life Field',
#        'Nissan Stadium', 'BC Place Stadium', 'Alamodome',
#        'Minute Maid Park', 'Chase Field', 'Dodger Stadium',
#        'Bryce Jordan Center', 'Legacy Arena at The BJCC',
#        'CHI Health Center Omaha', 'Vivint Smart Home Arena',
#        'Rogers Arena', 'Chase Center', 'T-Mobile Arena',
#        'Santander Performing Arts Center',
#        'Hackensack Meridian Health Theatre at the Count Basie Center for the Arts',
#        'Palace Theatre Albany', 'Truist Park', 'Hard Rock Stadium',
#        'Camping World Stadium', 'TIAA Bank Field', 'Busch Stadium',
#        'Wrigley Field', 'Hersheypark Stadium', 'FirstEnergy Stadium',
#        'Great American Ball Park', 'American Family Field',
#        'Kauffman Stadium', 'Coors Field', 'Fenway Park',
#        'Highmark Stadium', 'US Bank Stadium', 'State Farm Stadium',
#        'SoFi Stadium', 'Petco Park', 'T-Mobile Park', 'Oracle Park',
#        'SAP Center', 'Arena VFG', 'Estadio Foro Sol',
#        'New Orleans Fair Grounds', 'Raymond James Stadium',
#        'Cotton Bowl Stadium', 'Allegiant Stadium', 'Ford Field',
#        'Super Stage at Circuit of The Americas', 'The Wiltern',
#        'Ogden Theatre', 'Country Thunder USA - AZ',
#        'Broadmoor World Arena', 'American Bank Center',
#        'Tivoli Theatre - Chattanooga',
#        'Mississippi Moon Bar - Diamond Jo Casino',
#        'Brown Theatre at The Kentucky Center', 'Roxian Theatre',
#        'The National', '20 Monroe Live', 'BOK Center',
#        'Canadian Tire Centre', 'Moody Center ATX',
#        'American Family Insurance Amphitheater', 'Notre Dame Stadium',
#        'Cellairis Amphitheatre at Lakewood', 'Dos Equis Pavilion',
#        'The Cynthia Woods Mitchell Pavilion',
#        'Fiddlers Green Amphitheatre', 'Ak-Chin Pavilion',
#        'North Island Credit Union Amphitheatre', 'Nationwide Arena',
#        'UBS Arena', 'The Theatre at Resorts World Las Vegas',
#        'SaskTel Centre', 'Maverik Center', 'ExtraMile Arena',
#        'Honda Center', 'Bon Secours Wellness Arena', 'Resch Center',
#        'Tanglewood', 'Parc Jean-Drapeau', 'Lincoln Financial Field',
#        'Los Angeles Memorial Coliseum',
#        'Lake Tahoe Outdoor Arena at Harveys', 'Park Theater at Park MGM',
#        'Zappos Theater at Planet Hollywood', 'Isleta Amphitheater',
#        'Walmart AMP', 'Coastal Credit Union Music Park at Walnut Creek',
#        'Budweiser Stage', 'Darien Lake Amphitheater',
#        'Blossom Music Center', 'Ruoff Music Center', 'Jiffy Lube Live',
#        'Veterans United Home Loans Amphitheater', 'BB&T Pavilion',
#        'Northwell Health at Jones Beach Theater', 'Xfinity Theatre',
#        'PNC Bank Arts Center', 'Xfinity Center',
#        'Saratoga Performing Arts Center', 'DTE Energy Music Theatre',
#        'Hollywood Casino Amphitheatre', 'USANA Amphitheatre',
#        'Toyota Amphitheatre', 'Shoreline Amphitheatre',
#        'Concord Pavilion', 'White River Amphitheatre',
#        'Arena At Ford Idaho Center', 'Spokane Arena', 'Centre Videotron',
#        'Grand Ole Opry House', 'Budweiser Gardens', 'AT&T Stadium',
#        'Heinz Field', 'GEHA Field At Arrowhead Stadium',
#        'Bobcat Stadium - MSU', 'Lumen Field',
#        'Empower Field At Mile High', 'Merriweather Post Pavilion',
#        "Rick's Cafe", "Brewsky's",
#        "St. Joseph's Health Amphitheater at Lakeview", 'Mizzou Arena',
#        'Riverbend Music Center', 'United Supermarkets Arena',
#        'Frank Erwin Center', 'Hertz Arena', 'Huntington Center',
#        'Kroger Field', 'Sunlight Supply Amphitheater',
#        'Gorge Amphitheatre', 'Glen Helen Amphitheater',
#        'Mechanics Bank Arena', 'Ford Center', 'NRG Stadium',
#        'AT&T Center', 'SNHU Arena', 'The Anthem - D.C.',
#        'Sonoma County Fairgrounds',
#        'Hard Rock Live At The Seminole Hard Rock Hotel & Casino - Hollywood',
#        'Choctaw Casino & Resort - Durant',
#        'The Colosseum At Caesars Palace', 'Von Braun Center Arena',
#        'Peoria Civic Center - Arena', 'Fox Theatre - Detroit',
#        'Bristol Motor Speedway', 'Coosa Valley Fairgrounds',
#        'The Grounds - Mobile', 'Bourbon Theatre',
#        'Charleston Coliseum & Convention Center - Charleston',
#        'John Paul Jones Arena', 'The Wharf Amphitheatre',
#        'Berglund Center Coliseum', 'Cajundome',
#        'First National Bank Arena', 'Grossinger Motors Arena',
#        'Five Point Amphitheater', 'Save Mart Center',
#        'Brandon Amphitheater', 'Altria Theater - Richmond',
#        "Harrah's Cherokee Resort Event Center", 'Ovens Auditorium',
#        'Steven Tanger Center for the Performing Arts', 'Billy Bobs',
#        'South Plains Fair Park Coliseum', 'Midland County Amphitheater',
#        'Mcallen Convention Center', 'Hard Rock Live',
#        'Tuscaloosa Amphitheater', 'James Brown Arena',
#        'Stir Cove At Harrahs', 'TPC San Antonio', 'The Lyric - MS',
#        'Eight Seconds Saloon', 'Machine Shop', 'Payne Arena',
#        'Douglass Park', 'Harvard Athletic Complex',
#        'Matthew Knight Arena', 'Santa Barbara Bowl', 'Discovery Park',
#        'Daytona International Speedway',
#        'Barbara B Mann Performing Arts Hall', 'Lyric Opera House - MD',
#        'Blue Cross Arena', 'Mohegan Sun Arena at Casey Plaza',
#        'Riverside Theatre', 'Viejas Arena At Aztec Bowl',
#        'TaxSlayer Center', 'Marymoor Park', 'The Queen - Wilmington',
#        'Baltimore Soundstage', 'The Signal', 'The Castle Theatre',
#        'Zilker Park', 'Durham Performing Arts Center',
#        'Soldiers & Sailors Memorial Auditorium',
#        'ACL Live At The Moody Theater', 'UNO Lakefront Arena',
#        'The Chicago Theatre', 'Fabulous Fox Theatre', 'Beacon Theatre',
#        'Oxbow Riverstage', 'Arizona Federal Theatre',
#        'Downtown Las Vegas Events Center', 'Banc of California Stadium',
#        '401 Franklin Steet', 'Eventim Apollo'], dtype=object)

# %%
df_tickets['city'].unique()
# Out:
# array(['Milwaukee', 'Nashville', 'San Francisco', 'Spokane', 'Troutdale',
#        'Los Angeles', 'Las Vegas', 'Salt Lake City', 'Morrison', 'Mesa',
#        'New Orleans', 'Oklahoma City', 'Irving', 'Charlotte', 'Richmond',
#        'Pittsburgh', 'Uncasville', 'Cleveland', 'El Paso', 'Las Cruces',
#        'Glendale', 'Oakland', 'Tacoma', 'Portland', 'Vancouver',
#        'Edmonton', 'Calgary', 'Winnipeg', 'Sioux Falls', 'Minneapolis',
#        'Kansas City', 'St. Louis', 'Detroit', 'East Troy', 'Chicago',
#        'Hamilton', 'Toronto', 'Buffalo', 'Raleigh', 'Washington',
#        'New York', 'Houston', 'Dallas', 'Denver', 'Phoenix', 'Inglewood',
#        'Philadelphia', 'Flushing', 'San Bernardino', 'Memphis',
#        'Arlington', 'Gulf Shores', 'Fort Worth', 'Rosemont', 'Boston',
#        'Atlanta', 'Sunrise', 'San Diego', 'Independence', 'Columbus',
#        'Worcester', 'Norfolk', 'Laval', 'Orlando', 'Tampa', 'Miami',
#        'North Charleston', 'Duluth', 'Sacramento', 'Seattle', 'Rochester',
#        'Indianapolis', 'Birmingham', 'Santa Ana', 'Biloxi', 'Alpharetta',
#        'Jacksonville', 'Rapid City', 'Bethlehem', 'Atlantic City',
#        'Fort Lauderdale', 'Indio', 'Scottsdale', 'Laughlin',
#        'Wallingford', 'Amarillo', 'Berkeley', 'Sugar Land', 'Cedar Park',
#        'Sterling Heights', 'Baltimore', 'Austin', 'St. Petersburg',
#        'Miami Beach', 'Newport', 'Silver Spring', 'Anaheim', 'Greensboro',
#        'Grand Prairie', 'Cincinnati', 'Newark', 'Hampton', 'Columbia',
#        'Baton Rouge', 'Corpus Christi', 'Jackson', 'Brooklyn',
#        'Louisville', 'West Palm Beach', 'North Little Rock',
#        'Bossier City', 'Wichita', 'Lincoln', 'Burgettstown', 'Albany',
#        'London', 'Montreal', 'Uniondale', 'Fargo', 'Saint Paul',
#        'Des Moines', 'Grand Rapids', 'Knoxville', 'Lexington', 'Hershey',
#        'East Rutherford', 'Foxborough', 'Syracuse', 'San Antonio',
#        'University Park', 'Omaha', 'Reading', 'Red Bank', 'Miami Gardens',
#        'Orchard Park', 'San Jose', 'Guadalajara', 'Iztacalco', 'Florence',
#        'Colorado Springs', 'Chattanooga', 'Dubuque', 'Mckees Rocks',
#        'Tulsa', 'Ottawa', 'Notre Dame', 'Spring', 'Englewood',
#        'Chula Vista', 'Elmont', 'Saskatoon', 'Boise', 'Greenville',
#        'Green Bay', 'Lenox', 'Stateline', 'Albuquerque', 'Rogers',
#        'Darien Center', 'Cuyahoga Falls', 'Noblesville', 'Bristow',
#        'Virginia Beach', 'Camden', 'Wantagh', 'Hartford', 'Holmdel',
#        'Mansfield', 'Saratoga Springs', 'Clarkston', 'Tinley Park',
#        'Maryland Heights', 'Wheatland', 'Mountain View', 'Concord',
#        'Auburn', 'Nampa', 'Quebec', 'Bozeman', 'Starkville',
#        'Hattiesburg', 'Lubbock', 'Estero', 'Toledo', 'Ridgefield',
#        'Quincy', 'Bakersfield', 'Evansville', 'Manchester', 'Santa Rosa',
#        'Durant', 'Huntsville', 'Peoria', 'Bristol', 'Rome', 'Mobile',
#        'Charleston', 'Charlottesville', 'Orange Beach', 'Roanoke',
#        'Lafayette', 'Jonesboro', 'Bloomington', 'Irvine', 'Fresno',
#        'Brandon', 'Cherokee', 'Midland', 'Mcallen', 'Tuscaloosa',
#        'Augusta', 'Council Bluffs', 'Oxford', 'Flint', 'Hidalgo',
#        'Cambridge', 'Eugene', 'Santa Barbara', 'Daytona Beach',
#        'Fort Myers', 'Wilkes Barre', 'Moline', 'Redmond', 'Wilmington',
#        'Durham', 'Napa'], dtype=object)

# %%
df_tickets['state'].unique()
# Out:
# array(['WI', 'TN', 'CA', 'WA', 'OR', 'NV', 'UT', 'CO', 'AZ', 'LA', 'OK',
#        'TX', 'NC', 'VA', 'PA', 'CT', 'OH', 'NM', 'BC', 'AB', 'MB', 'SD',
#        'MN', 'MO', 'MI', 'IL', 'ON', 'NY', 'DC', 'AL', 'MA', 'GA', 'FL',
#        'QC', 'SC', 'IN', 'MS', 'NJ', 'MD', 'KY', 'AR', 'KS', 'NE', 'GL',
#        'ND', 'IA', 'JA', 'CD', 'SK', 'ID', 'MT', 'NH', 'WV', 'DE'],
#       dtype=object)

# %%
df_tickets['date'].unique()
# Out:
# array(['Oct 05 2021', 'Oct 06 2021', 'Oct 10 2021', 'Oct 12 2021',
#        'Oct 13 2021', 'Oct 15 2021', 'Oct 16 2021', 'Oct 17 2021',
#        'Oct 18 2021', 'Oct 20 2021', 'Oct 21 2021', 'Oct 22 2021',
#        'Oct 23 2021', 'Oct 24 2021', 'Oct 27 2021', 'Oct 28 2021',
#        'Oct 30 2021', 'Oct 31 2021', 'Dec 18 2021', 'Mar 31 2022',
#        'Apr 02 2022', 'Apr 04 2022', 'Apr 06 2022', 'Apr 26 2022',
#        'Apr 28 2022', 'Apr 30 2022', 'May 02 2022', 'May 05 2022',
#        'May 07 2022', 'May 09 2022', 'May 11 2022', 'May 13 2022',
#        'May 15 2022', 'May 16 2022', 'May 18 2022', 'May 20 2022',
#        'May 22 2022', 'May 23 2022', 'Jul 09 2022', 'Jul 11 2022',
#        'Jul 12 2022', 'Jul 19 2022', 'Jul 21 2022', 'Jul 23 2022',
#        'Jul 25 2022', 'Jul 27 2022', 'Jul 29 2022', 'Jul 31 2022',
#        'Aug 02 2022', 'Aug 03 2022', 'Aug 08 2022', 'Aug 09 2022',
#        'Aug 11 2022', 'Aug 12 2022', 'Aug 14 2022', 'Oct 07 2021',
#        'Oct 11 2021', 'Oct 14 2021', 'Oct 25 2021', 'Dec 10 2021',
#        'Apr 29 2022', 'Nov 30 2021', 'Dec 03 2021', 'Dec 07 2021',
#        'Dec 12 2021', 'Dec 13 2021', 'Dec 14 2021', 'Dec 16 2021',
#        'Dec 19 2021', 'Apr 03 2070', 'TBD', 'Feb 10 2022', 'Feb 11 2022',
#        'Feb 12 2022', 'Feb 14 2022', 'Feb 16 2022', 'Feb 18 2022',
#        'Feb 19 2022', 'Feb 20 2022', 'Feb 22 2022', 'Feb 24 2022',
#        'Feb 27 2022', 'Feb 28 2022', 'Mar 03 2022', 'Mar 04 2022',
#        'Mar 06 2022', 'Mar 07 2022', 'Mar 09 2022', 'Mar 11 2022',
#        'Mar 12 2022', 'Mar 13 2022', 'Mar 14 2022', 'Mar 16 2022',
#        'Mar 18 2022', 'Mar 19 2022', 'Mar 20 2022', 'Mar 23 2022',
#        'Mar 25 2022', 'Mar 27 2022', 'Mar 29 2022', 'Apr 01 2022',
#        'Apr 07 2022', 'Apr 08 2022', 'Nov 05 2021', 'Oct 26 2021',
#        'Oct 29 2021', 'Nov 02 2021', 'Nov 06 2021', 'Nov 07 2021',
#        'Nov 09 2021', 'Nov 10 2021', 'Nov 12 2021', 'Nov 13 2021',
#        'Nov 15 2021', 'Nov 16 2021', 'Nov 17 2021', 'Nov 19 2021',
#        'Nov 20 2021', 'May 09 2070', 'Nov 27 2021', 'Dec 11 2021',
#        'Oct 09 2021', 'May 27 2022', 'May 28 2022', 'Mar 28 2022',
#        'Apr 10 2022', 'Apr 14 2022', 'Oct 08 2021', 'May 01 2022',
#        'May 03 2022', 'May 06 2022', 'May 14 2022', 'May 17 2022',
#        'May 19 2022', 'May 25 2022', 'May 26 2022', 'May 29 2022',
#        'May 31 2022', 'Jun 02 2022', 'Jun 03 2022', 'Jun 05 2022',
#        'Jun 08 2022', 'Jun 09 2022', 'Jun 11 2022', 'Oct 19 2021',
#        'Nov 01 2021', 'Nov 03 2021', 'Nov 23 2021', 'Nov 24 2021',
#        'Nov 26 2021', 'Nov 28 2021', 'Nov 14 2021', 'Nov 21 2021',
#        'Jan 15 2022', 'Nov 04 2021', 'Jan 19 2022', 'Jan 21 2022',
#        'Jan 22 2022', 'Jan 25 2022', 'Jan 26 2022', 'Jan 29 2022',
#        'Jan 30 2022', 'Feb 01 2022', 'Feb 04 2022', 'Feb 05 2022',
#        'Feb 08 2022', 'Feb 09 2022', 'Feb 15 2022', 'Feb 23 2022',
#        'Feb 25 2022', 'Mar 01 2022', 'Mar 02 2022', 'Mar 05 2022',
#        'Mar 22 2022', 'Mar 26 2022', 'Mar 30 2022', 'Apr 05 2022',
#        'Apr 09 2022', 'Apr 12 2022', 'Apr 13 2022', 'Apr 16 2022',
#        'Apr 19 2022', 'Apr 20 2022', 'Apr 23 2022', 'Apr 24 2022',
#        'Apr 27 2022', 'Jun 24 2022', 'Jul 15 2022', 'Jul 18 2022',
#        'Jul 28 2022', 'Jul 30 2022', 'Aug 05 2022', 'Sep 07 2022',
#        'Sep 10 2022', 'Sep 16 2022', 'Sep 18 2022', 'Sep 22 2022',
#        'Sep 24 2022', 'Sep 30 2022', 'Oct 02 2022', 'Oct 21 2022',
#        'Oct 29 2022', 'Nov 04 2022', 'Nov 12 2022', 'Nov 19 2022',
#        'Nov 20 2022', 'Feb 03 2022', 'Feb 06 2022', 'Feb 13 2022',
#        'Mar 08 2022', 'Mar 15 2022', 'Mar 21 2022', 'Mar 24 2022',
#        'Apr 03 2022', 'Jun 10 2022', 'Jun 12 2022', 'Jun 16 2022',
#        'Jun 25 2022', 'Jun 26 2022', 'Apr 15 2022', 'Jun 18 2022',
#        'Jun 19 2022', 'Jun 22 2022', 'Jun 28 2022', 'Jun 30 2022',
#        'Jul 02 2022', 'Jul 05 2022', 'Jul 08 2022', 'Jul 10 2022',
#        'Jul 14 2022', 'Jul 17 2022', 'Aug 06 2022', 'Aug 10 2022',
#        'Aug 19 2022', 'Aug 21 2022', 'Aug 22 2022', 'Aug 25 2022',
#        'Aug 27 2022', 'Aug 28 2022', 'Aug 31 2022', 'Nov 08 2021',
#        'Nov 11 2021', 'Oct 01 2070', 'Nov 18 2021', 'Nov 29 2021',
#        'Dec 02 2021', 'Dec 08 2021', 'Dec 15 2021', 'Jan 06 2022',
#        'Jan 07 2022', 'Jan 08 2022', 'Jan 13 2022', 'Jan 14 2022',
#        'Dec 01 2021', 'Feb 26 2022', 'Apr 11 2022', 'Apr 21 2022',
#        'Apr 25 2022', 'May 04 2022', 'May 10 2022', 'May 12 2022',
#        'Jun 07 2022', 'Jun 13 2022', 'Jun 14 2022', 'Jun 20 2022',
#        'Dec 20 2021', 'Nov 22 2021', 'Nov 25 2021', 'Dec 05 2021',
#        'Dec 06 2021', 'Mar 17 2022', 'Jan 28 2022', 'Feb 02 2022',
#        'Apr 22 2022', 'May 30 2022', 'Dec 04 2021', 'Jul 04 2022',
#        'Sep 03 2022', 'Sep 06 2022', 'Sep 09 2022', 'Sep 17 2022',
#        'Sep 23 2022', 'Feb 17 2022', 'Feb 21 2022', 'Dec 22 2021',
#        'Dec 23 2021', 'Jun 04 2022', 'Jun 15 2022', 'Jun 17 2022',
#        'Jun 21 2022', 'Jul 01 2022', 'Jul 03 2022', 'Jul 06 2022',
#        'Jul 13 2022', 'Jul 16 2022', 'Jul 20 2022', 'Aug 04 2022',
#        'Aug 07 2022', 'Aug 24 2022', 'Sep 02 2022', 'Sep 11 2022',
#        'Sep 13 2022', 'Sep 14 2022', 'May 21 2022', 'Aug 13 2022',
#        'Aug 20 2022', 'Aug 26 2022', 'Jun 23 2022', 'Jan 20 2022',
#        'Jan 27 2022', 'Dec 17 2021', 'Dec 09 2021', 'Mar 10 2022',
#        'Jan 17 2022', 'Jan 23 2022', 'Jan 24 2022', 'Aug 29 2022',
#        'Sep 05 2022', 'Sep 15 2022', 'Sep 20 2022', 'Sep 21 2022',
#        'Sep 27 2022', 'Sep 28 2022', 'Oct 03 2022', 'Oct 05 2022',
#        'Oct 07 2022', 'Oct 11 2022', 'Oct 12 2022', 'Oct 14 2022',
#        'Oct 15 2022', 'Dec 29 2021', 'Dec 30 2021', 'Dec 31 2021',
#        'Jan 01 2022', 'Dec 26 2021', 'Dec 27 2021', 'Dec 28 2021',
#        'Jan 10 2022', 'Jan 11 2022', 'Jan 16 2022', 'Jan 18 2022',
#        'Jan 31 2022'], dtype=object)

# %%
df_tickets['time'].unique()
# Out:
# array(['7:30 PM', '8:00 PM', '6:30 PM', '6:00 PM', '2021 TBD', '7:00 PM',
#        '2022 TBD', '5:00 PM', '2070 TBD', 'ostponed', '12:00 PM',
#        '8:30 PM', '4:30 PM', '10:00 AM', '11:00 AM', '4:00 PM',
#        '12:00 AM', '10:00 PM', '9:30 PM', '9:00 PM', '8:45 PM'],
#       dtype=object)

# %%
#remove the less occuring venues, because this will improve the model
df_tickets = df_tickets[df_tickets['venue'].map(df_tickets['venue'].value_counts() >= 500)]

# %%
#excluding incorrect values
df_tickets = df_tickets[(df_tickets.date != 'TBD')]
df_tickets = df_tickets[(df_tickets.time != '2021 TBD') & (df_tickets.time != '2070 TBD') 
                        & (df_tickets.time != '2022 TBD') & (df_tickets.time != 'ostponed')] #postponed

# %%
#convert the date feature from object to datetime
df_tickets.date = pd.to_datetime(df_tickets.date)

df_tickets['month'] = df_tickets.date.dt.month
df_tickets['year'] = df_tickets.date.dt.year
df_tickets['day'] = df_tickets.date.dt.weekday #monday is 0

df_tickets.time = pd.to_datetime(df_tickets.time).dt.hour

# %%
#drop columns data and date
df_tickets.drop(columns = ['data','date'], inplace = True)

# %% [markdown]
# ### Exploring and Cleaning the Level Feature

# %%
#clean the levels, try to unify them
new_level = []
for lev in tqdm(df_tickets['level'].str.upper()):
    lev = lev.strip()
    if 'DAY' in lev or 'RESERVED' in lev or 'PACKAGE' in lev or 'TBD' in lev:
        new_level.append('drop') #making it easier to drop later
        continue
    elif 'VIP' in lev:
        new_level.append('VIP')
    elif 'GA' in lev or 'General Admission'.upper() in lev or 'G.A' in lev or 'GENADM' in lev or 'G/A' in lev:
        new_level.append('GA')
    elif 'CENTER' in lev:
        new_level.append('CENTER')
    elif 'LEFT' in lev or 'LFT' in lev:
        new_level.append('LEFT')
    elif 'RIGHT' in lev:
        new_level.append('RIGHT')
    elif 'LAWN' in lev:
        new_level.append('LAWN')
    elif 'TERRACE' in lev:
        new_level.append('TERRACE')
    elif 'BALCONY' in lev or 'BAL' in lev:
        new_level.append('BALCONY')
    elif 'BENCH' in lev:
        new_level.append('BENCH')
    elif 'FLOOR' in lev or 'FLR' in lev or 'FL' in lev:
        new_level.append('FLOOR')
    elif 'SUITE' in lev:
        new_level.append('SUITE')
    elif 'UPPER' in lev or 'UR' in lev:
        new_level.append('UPPER')
    elif 'LOWER' in lev or 'LR' in lev:
        new_level.append('LOWER')
    elif 'LOGE' in lev:
        new_level.append('LOGE')
    elif 'GROUND' in lev:
        new_level.append('GROUND')
    elif 'CON' in lev:
        new_level.append('CONCOURSE')
    elif 'RISERS' in lev:
        new_level.append('RISERS')
    elif 'MEZ' in lev:
        new_level.append('MEZZANINE')
    elif 'ORCHESTRA' in lev or 'ORCH' in lev:
        new_level.append('ORCHESTRA')
    elif 'STADIUM' in lev:
        new_level.append('STADIUM')
    elif 'PAVILLION' in lev:
        new_level.append('PAVILLION')
    elif 'TABL' in lev:
        new_level.append('TABLE')
    elif 'GRAND SALLE' in lev:
        new_level.append('GRAND SALLE')
    elif 'PIT' in lev:
        new_level.append('PIT')
    elif 'PLAT' in lev:
        new_level.append('PLATINUM')
    elif 'GRAND' in lev:
        new_level.append('GRAND')
    elif 'DIAMOND' in lev:
        new_level.append('DIAMOND')
    elif 'CLUB' in lev or 'CLB' in lev:
        new_level.append('CLUB')
    elif 'BLEACHERS' in lev:
        new_level.append('BLEACHERS')
    elif 'BOX' in lev:
        new_level.append('BOX')
    elif 'PR' in lev:
        new_level.append('PR')
    elif 'SECTION' in lev or 'FIELD' in lev:
        val = lev.split()[1].strip()
        if 'SEC' in val or 'PART' in val:
            new_level.append(val[-1])
        elif val.isnumeric():
            #check for leading zeros
            if val[0] == '0':
                val = val[1:]
            #split into ranges
            if int(val) in range(1,100):
                new_level.append('level-0')
            elif int(val) in range(100,200):
                new_level.append('level-1')
            elif int(val) in range(200,300):
                new_level.append('level-2')
            elif int(val) in range(300,400):
                new_level.append('level-3')
            elif int(val) in range(400,500):
                new_level.append('level-4')
            elif int(val) in range(500,600):
                new_level.append('level-5')
            elif int(val) in range(600,700):
                new_level.append('level-6')
            else:
                new_level.append('level-7')
        elif val.isalpha():
            if len(val) == 2 and val[0] == val[1]:
                new_level.append(val[0])
            else:
                new_level.append(val)
        else: 
            chars = ''
            for char in val:
                if char.isalpha():
                    chars += char
            new_level.append(chars)
    else:
        new_level.append('OTHER')
# Out:
# 100%|██████████| 62000/62000 [00:00<00:00, 95339.84it/s]

# %%
#store list to df_tickets
df_tickets['level'] = new_level

# %%
#drop the leveles we excluded
df_tickets = df_tickets[df_tickets['level'] != 'drop']

# %%
df_tickets['level'].nunique()
# Out:
# 62

# %%
df_tickets['level'].value_counts()[:50]
# Out:
# level-1      24300
# level-2      11642
# level-3       8647
# level-0       4332
# FLOOR         1692
# level-4       1185
# GA             915
# C              913
# ORCHESTRA      716
# MEZZANINE      575
# A              540
# BALCONY        539
# level-5        479
# F              455
# LOGE           428
# UPPER          407
# TERRACE        406
# PR             360
# B              321
# LOWER          304
# M              279
# OTHER          240
# D              235
# BOX            233
# E              205
# V              154
# GRAND          128
# G              122
# CL             111
# H               92
# SUITE           88
# J               83
# K               79
# RIGHT           78
# VIP             77
# P               69
# L               63
# N               51
# PIT             51
# Q               40
# CLUB            36
# T               34
# U               33
# LEFT            22
# R               21
# CB              21
# W               17
# S                9
# SL               9
# DRM              8
# Name: level, dtype: int64

# %%
df_tickets = df_tickets[df_tickets['level'] != '']

# %% [markdown]
# ### Exploring and Cleaning the Price Feature

# %%
df_tickets['price'].head()
# Out:
# 1011    $138
# 1012    $147
# 1014    $157
# 1017    $142
# 1019    $221
# Name: price, dtype: object

# %%
#remove dolar sign and convert it to float
df_tickets['price'] = df_tickets['price'].str.replace('$',"").str.replace(",","").astype(float)

# %%
#checking for outliers
plt.figure(figsize=(20,5))
sns.boxplot("price", data=df_tickets);

# %%
plt.figure(figsize=(20,5))
Q1 = df_tickets['price'].quantile(0.25)
Q3 = df_tickets['price'].quantile(0.75)
IQR = Q3 - Q1 
sns.boxplot("price", data=df_tickets.loc[(df_tickets['price'] >= Q1 - 1.5 * IQR) 
                                         & (df_tickets['price'] <= Q3 + 1.5 *IQR)]);

# %%
#remove the outlier
df_tickets = df_tickets.loc[(df_tickets['price'] >= Q1 - 1.5 * IQR) & (df_tickets['price'] <= Q3 + 1.5 *IQR)]
df_tickets
# Out:
#                    artist    level  price                 venue         city  \
# 1011    Machine Gun Kelly  level-0  138.0     Mohegan Sun Arena   Uncasville
# 1012    Machine Gun Kelly  level-0  147.0     Mohegan Sun Arena   Uncasville
# 1014    Machine Gun Kelly  level-0  157.0     Mohegan Sun Arena   Uncasville
# 1017    Machine Gun Kelly  level-0  142.0     Mohegan Sun Arena   Uncasville
# 1019    Machine Gun Kelly  level-0  221.0     Mohegan Sun Arena   Uncasville
# ...                   ...      ...    ...                   ...          ...
# 180088     Dave Chappelle  level-3   98.0  Smoothie King Center  New Orleans
# 180089     Dave Chappelle  level-1  438.0  Smoothie King Center  New Orleans
# 180090     Dave Chappelle  level-3  152.0  Smoothie King Center  New Orleans
# 180091     Dave Chappelle  level-3  209.0  Smoothie King Center  New Orleans
# 180092     Dave Chappelle  level-1  250.0  Smoothie King Center  New Orleans
#
#        state  time  month  year  day
# 1011      CT    19     10  2021    6
# 1012      CT    19     10  2021    6
# 1014      CT    19     10  2021    6
# 1017      CT    19     10  2021    6
# 1019      CT    19     10  2021    6
# ...      ...   ...    ...   ...  ...
# 180088    LA    20     10  2021    3
# 180089    LA    20     10  2021    3
# 180090    LA    20     10  2021    3
# 180091    LA    20     10  2021    3
# 180092    LA    20     10  2021    3
#
# [57766 rows x 10 columns]

# %%
plt.figure(figsize=(10,5))
plt.hist(df_tickets.price, bins=500)
plt.title('The Distribution of Concert Ticket Prices');

# %% [markdown]
# ### EDA & Visualization of the Tickets Dataset

# %%
#defining colors
red = sns.color_palette("Spectral")[0]
orange = sns.color_palette("Spectral")[1]

# %% [markdown]
# #### Ticket Prices per Artist per Day
# It is not very interpretable because the data is too huge, however, it is evident that Friday, Saturday, and Sunday are the most occuring

# %%
sns.catplot(y='price', x='artist', hue='day', data=df_tickets, height=5, aspect=4, alpha=0.3)
plt.xticks(rotation='90')
plt.title('Ticket Prices per Artist per Day');

# %% [markdown]
# #### Ticket Prices per Venue
# It is evident that the price range varies across most venues.

# %%
sns.catplot(y='price', x='venue', data=df_tickets, color=orange, alpha=0.3, height=5, aspect=3)
plt.xticks(rotation='90')
plt.title('Ticket Prices per Venue');

# %% [markdown]
# #### Top 10 Artists with the Highest Average Ticket Price

# %%
df_artist = df_tickets.groupby('artist').mean()['price'].sort_values(ascending=False)
df_artist.head()
# Out:
# artist
# BTS - Bangtan Boys    475.080000
# Dead & Company        441.317568
# Bad Bunny             382.346354
# Harry Styles          379.690828
# Jenny Lewis           365.770627
# Name: price, dtype: float64

# %%
plt.figure(figsize=(20,5))
plt.bar(x=df_artist.index[:10], height=df_artist[:10], color=red)
plt.xlabel('Artist', fontsize=15)
plt.ylabel('Ticket Price', fontsize=15)
plt.title('Top 10 Artists with the Highest Average Ticket Price', fontsize=20);

# %%
sns.catplot(x='artist', y='price', data=df_artist.reset_index(), height=5, aspect=3)
plt.xticks(rotation='90')
plt.xlabel('Artist', fontsize=10)
plt.ylabel('Ticket Price', fontsize=10)
plt.title('Artists and Their Average Ticket Price', fontsize=15);

# %% [markdown]
# #### Top 10 Venues with the Highest Average Ticket Price

# %%
df_venue = df_tickets.groupby('venue').mean()['price'].sort_values(ascending=False)
df_venue.head()
# Out:
# venue
# The Colosseum At Caesars Palace    345.885122
# SoFi Stadium                       316.754525
# Fenway Park                        303.338663
# Barclays Center                    291.907937
# Capital One Arena                  284.221477
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df_venue.index[:10], x=df_venue[:10], color=orange)
plt.xlabel('Ticket Price', fontsize=10)
plt.ylabel('Venue', fontsize=10)
plt.title('Top 10 Venues with the Highest Average Ticket Price', fontsize=15);

# %% [markdown]
# #### Top 10 Cities with the Highest Average Ticket Price

# %%
df_city = df_tickets.groupby('city').mean()['price'].sort_values(ascending=False)
df_city.head()
# Out:
# city
# Brooklyn      291.907937
# Boston        288.264984
# Washington    284.221477
# Oakland       278.100139
# Sunrise       276.251469
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df_city.index[:10], x=df_city[:10], color=red)
plt.xlabel('Ticket Price', fontsize=10)
plt.ylabel('City', fontsize=10)
plt.title('Top 10 Cities with the Highest Average Ticket Price', fontsize=15);

# %% [markdown]
# #### Top 10 States with the Highest Average Ticket Price

# %%
df_state = df_tickets.groupby('state').mean()['price'].sort_values(ascending=False)
df_state.head()
# Out:
# state
# MA    288.264984
# DC    284.221477
# ON    271.878700
# NV    271.857270
# CT    260.968900
# Name: price, dtype: float64

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df_state.index[:10], y=df_state[:10], color=orange)
plt.xlabel('Ticket Price', fontsize=10)
plt.ylabel('State', fontsize=10)
plt.title('Top 10 States with the Highest Average Ticket Price', fontsize=15);

# %% [markdown]
# ## Salaries Data

# %%
#reading file
df_salaries = pd.read_csv('salaries.csv')
df_salaries.columns = ['state','median_salary','avg_salary']
df_salaries
# Out:
#                    state median_salary avg_salary
# 0   District of Columbia       $71,690   $115,923
# 1          Massachusetts       $48,680    $76,437
# 2                 Alaska       $48,020    $69,789
# 3            Connecticut       $46,920    $74,405
# 4             Washington       $46,100    $74,016
# 5               New York       $44,990    $80,640
# 6               Maryland       $44,690    $69,893
# 7             New Jersey       $43,600    $71,959
# 8              Minnesota       $42,630    $62,156
# 9                 Hawaii       $42,480    $59,231
# 10            California       $42,430    $75,400
# 11              Colorado       $42,310    $62,375
# 12          Rhode Island       $42,040    $59,055
# 13          North Dakota       $41,340    $55,447
# 14              Virginia       $40,820    $64,517
# 15               Wyoming       $40,240    $55,018
# 16              Illinois       $39,950    $66,600
# 17              Delaware       $39,900    $62,817
# 18         New Hampshire       $39,870    $62,427
# 19               Vermont       $39,720    $50,826
# 20                Oregon       $39,580    $60,306
# 21          Pennsylvania       $38,450    $64,706
# 22             Wisconsin       $37,970    $56,302
# 23              Michigan       $37,620    $58,132
# 24                  Ohio       $37,360    $57,764
# 25              Nebraska       $37,130    $56,147
# 26                 Maine       $37,120    $50,441
# 27                  Iowa       $37,100    $52,467
# 28                 Texas       $37,100    $62,230
# 29               Arizona       $37,020    $57,422
# 30                  Utah       $36,790    $54,075
# 31              Missouri       $36,040    $54,580
# 32               Georgia       $35,950    $58,280
# 33                Kansas       $35,950    $54,109
# 34        North Carolina       $35,750    $56,343
# 35               Indiana       $35,730    $56,754
# 36                Nevada       $35,550    $54,842
# 37               Montana       $35,080    $46,424
# 38             Tennessee       $34,890    $59,121
# 39              Kentucky       $34,650    $50,701
# 40               Florida       $34,560    $52,728
# 41              Oklahoma       $34,560    $55,204
# 42                 Idaho       $34,260    $49,763
# 43            New Mexico       $34,120    $50,893
# 44        South Carolina       $33,750    $51,670
# 45               Alabama       $33,740    $51,347
# 46          South Dakota       $33,450    $49,827
# 47             Louisiana       $33,390    $53,095
# 48         West Virginia       $32,640    $51,679
# 49              Arkansas       $31,850    $48,164
# 50           Mississippi       $30,580    $44,285
# 51           Puerto Rico    $20,100[3]    No data

# %%
df_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   median_salary  52 non-null     object
#  2   avg_salary     52 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
#clean the last row
df_salaries['median_salary'][51] = '$20,100'
df_salaries['avg_salary'][51] = df_salaries['median_salary'][51]

# %%
#remove dolar sign and convert it to float
df_salaries['median_salary'] = df_salaries['median_salary'].str.replace('$',"").str.replace(",","").astype(float)
df_salaries['avg_salary'] = df_salaries['avg_salary'].str.replace('$',"").str.replace(",","").astype(float)

# %%
#dictionary to convert state to abbreviation
state_to_abbrev = {"Alabama": "AL", "Alaska": "AK","Arizona": "AZ","Arkansas": "AR","California": "CA",
                   "Colorado": "CO","Connecticut": "CT","Delaware": "DE","Florida": "FL","Georgia": "GA",
                   "Hawaii": "HI","Idaho": "ID","Illinois": "IL","Indiana": "IN","Iowa": "IA","Kansas": "KS",
                   "Kentucky": "KY","Louisiana": "LA","Maine": "ME","Maryland": "MD","Massachusetts": "MA",
                   "Michigan": "MI","Minnesota": "MN","Mississippi": "MS","Missouri": "MO","Montana": "MT",
                   "Nebraska": "NE","Nevada": "NV","New Hampshire": "NH","New Jersey": "NJ","New Mexico": "NM",
                   "New York": "NY","North Carolina": "NC","North Dakota": "ND","Ohio": "OH","Oklahoma": "OK",
                   "Oregon": "OR","Pennsylvania": "PA","Rhode Island": "RI","South Carolina": "SC",
                   "South Dakota": "SD","Tennessee": "TN","Texas": "TX","Utah": "UT", "Vermont": "VT",
                   "Virginia": "VA","Washington": "WA","West Virginia": "WV","Wisconsin": "WI","Wyoming": "WY",
                   "District of Columbia": "DC","American Samoa": "AS","Guam": "GU","Northern Mariana Islands": "MP",
                   "Puerto Rico": "PR","United States Minor Outlying Islands": "UM","U.S. Virgin Islands": "VI"}

# %%
#replacing a state with its abbreviation
df_salaries['state'] = df_salaries['state'].map(state_to_abbrev)

# %%
df_salaries.head()
# Out:
#   state  median_salary  avg_salary
# 0    DC        71690.0    115923.0
# 1    MA        48680.0     76437.0
# 2    AK        48020.0     69789.0
# 3    CT        46920.0     74405.0
# 4    WA        46100.0     74016.0

# %% [markdown]
# ## Final Dataset

# %%
df = pd.merge(df_tickets, df_salaries, on='state')
df
# Out:
#                   artist    level  price                    venue  \
# 0      Machine Gun Kelly  level-0  138.0        Mohegan Sun Arena
# 1      Machine Gun Kelly  level-0  147.0        Mohegan Sun Arena
# 2      Machine Gun Kelly  level-0  157.0        Mohegan Sun Arena
# 3      Machine Gun Kelly  level-0  142.0        Mohegan Sun Arena
# 4      Machine Gun Kelly  level-0  221.0        Mohegan Sun Arena
# ...                  ...      ...    ...                      ...
# 54229     Andrea Bocelli  level-0  442.0  Vivint Smart Home Arena
# 54230     Andrea Bocelli  level-1  131.0  Vivint Smart Home Arena
# 54231     Andrea Bocelli  level-0  469.0  Vivint Smart Home Arena
# 54232     Andrea Bocelli  level-0  444.0  Vivint Smart Home Arena
# 54233     Andrea Bocelli  level-1  263.0  Vivint Smart Home Arena
#
#                  city state  time  month  year  day  median_salary  avg_salary
# 0          Uncasville    CT    19     10  2021    6        46920.0     74405.0
# 1          Uncasville    CT    19     10  2021    6        46920.0     74405.0
# 2          Uncasville    CT    19     10  2021    6        46920.0     74405.0
# 3          Uncasville    CT    19     10  2021    6        46920.0     74405.0
# 4          Uncasville    CT    19     10  2021    6        46920.0     74405.0
# ...               ...   ...   ...    ...   ...  ...            ...         ...
# 54229  Salt Lake City    UT    19     10  2021    5        36790.0     54075.0
# 54230  Salt Lake City    UT    19     10  2021    5        36790.0     54075.0
# 54231  Salt Lake City    UT    19     10  2021    5        36790.0     54075.0
# 54232  Salt Lake City    UT    19     10  2021    5        36790.0     54075.0
# 54233  Salt Lake City    UT    19     10  2021    5        36790.0     54075.0
#
# [54234 rows x 12 columns]

# %%
#for later use
df_copy = df.copy()

# %% [markdown]
# ### Creating binary column for classification

# %%
df['price_class'] = df.price
df['price_class'][df['price'] >= df.price.mean()] = 1 #'Expensive'
df['price_class'][df['price'] < df.price.mean()] =  0 #'Cheap'

df.price_class.value_counts()
# Out:
# 0.0    31858
# 1.0    22376
# Name: price_class, dtype: int64

# %%
#trying to see if we can predict for one level
#df = df[df.level == 'GA']

# %%
df.columns
# Out:
# Index(['artist', 'level', 'price', 'venue', 'city', 'state', 'time', 'month',
#        'year', 'day', 'median_salary', 'avg_salary', 'price_class'],
#       dtype='object')

# %%
#final clean dataset -> used to visualize in Tableau
df.to_csv('Concert_Tickets.csv', index= False)

# %% [markdown]
# ### Encode the Categorical Variables

# %%
le = preprocessing.LabelEncoder()
le.fit(df.artist)
df.artist = list(le.transform(df.artist))

# %%
le = preprocessing.LabelEncoder()
le.fit(df.venue)
df.venue = list(le.transform(df.venue))

# %%
le = preprocessing.LabelEncoder()
le.fit(df.city)
df.city = list(le.transform(df.city))

# %%
le = preprocessing.LabelEncoder()
le.fit(df.state)
df.state = list(le.transform(df.state))

# %%
le = preprocessing.LabelEncoder()
le.fit(df.level)
df.level = list(le.transform(df.level))

# %%
df
# Out:
#        artist  level  price  venue  city  state  time  month  year  day  \
# 0          45     54  138.0     32    49      3    19     10  2021    6
# 1          45     54  147.0     32    49      3    19     10  2021    6
# 2          45     54  157.0     32    49      3    19     10  2021    6
# 3          45     54  142.0     32    49      3    19     10  2021    6
# 4          45     54  221.0     32    49      3    19     10  2021    6
# ...       ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 54229       1     54  442.0     57    38     25    19     10  2021    5
# 54230       1     55  131.0     57    38     25    19     10  2021    5
# 54231       1     54  469.0     57    38     25    19     10  2021    5
# 54232       1     54  444.0     57    38     25    19     10  2021    5
# 54233       1     55  263.0     57    38     25    19     10  2021    5
#
#        median_salary  avg_salary  price_class
# 0            46920.0     74405.0          0.0
# 1            46920.0     74405.0          0.0
# 2            46920.0     74405.0          0.0
# 3            46920.0     74405.0          0.0
# 4            46920.0     74405.0          0.0
# ...              ...         ...          ...
# 54229        36790.0     54075.0          1.0
# 54230        36790.0     54075.0          0.0
# 54231        36790.0     54075.0          1.0
# 54232        36790.0     54075.0          1.0
# 54233        36790.0     54075.0          1.0
#
# [54234 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54234 entries, 0 to 54233
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist         54234 non-null  int64
#  1   level          54234 non-null  int64
#  2   price          54234 non-null  float64
#  3   venue          54234 non-null  int64
#  4   city           54234 non-null  int64
#  5   state          54234 non-null  int64
#  6   time           54234 non-null  int64
#  7   month          54234 non-null  int64
#  8   year           54234 non-null  int64
#  9   day            54234 non-null  int64
#  10  median_salary  54234 non-null  float64
#  11  avg_salary     54234 non-null  float64
#  12  price_class    54234 non-null  float64
# dtypes: float64(4), int64(9)
# memory usage: 5.8 MB

# %% [markdown]
# ### Correlation Between the Variables

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# #### There is high correlation between the median and average salary, therefore, we will exclude the median salary from the train set.

# %%
sns.pairplot(df, x_vars=['artist', 'level', 'venue','city','state','time'],y_vars=['price'], height= 3, aspect=1);

# %%
sns.pairplot(df, x_vars=['month','year', 'day','median_salary', 'avg_salary'],y_vars=['price'], height= 3, aspect=1);

# %%
df.columns
# Out:
# Index(['artist', 'level', 'price', 'venue', 'city', 'state', 'time', 'month',
#        'year', 'day', 'median_salary', 'avg_salary', 'price_class'],
#       dtype='object')

# %% [markdown]
# ## Regression

# %%
features = ['artist', 'level', 'venue', 'city', 'state', 'day','time', 'month', 'year', 'avg_salary']
X = df[features]
y = df.price

# split 80% of the data to the training set while 20% of the data to test set
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.20) 
# split 75% of the data to the training set while 25% of the data to validation set
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25)

# %% [markdown]
# ### Linear Regression

# %%
def LinReg(X_train, y_train, X_val, y_val):
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    r_squared = model.score(X_val, y_val)
    MAE_ = metrics.mean_absolute_error(y_val, y_pred)
    MSE_ = metrics.mean_squared_error(y_val, y_pred)
    RMSE_ = np.sqrt(MSE_)
    return [r_squared, MAE_, MSE_, RMSE_]

# %% [markdown]
# ### Polynomial Features

# %%
def Polynomial(X_train, y_train, X_val, y_val, degree):
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    r_squared = model.score(X_val, y_val)
    MAE_ = metrics.mean_absolute_error(y_val, y_pred)
    MSE_ = metrics.mean_squared_error(y_val, y_pred)
    RMSE_ = np.sqrt(MSE_)
    return [r_squared, MAE_, MSE_, RMSE_]

# %% [markdown]
# ### Decision Tree Regressor

# %%
def DTree_Reg(X_train, y_train, X_val, y_val, depth):
    model = DecisionTreeRegressor(max_depth= depth, random_state = 1)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    r_squared = model.score(X_val, y_val)
    MAE_ = metrics.mean_absolute_error(y_val, y_pred)
    MSE_ = metrics.mean_squared_error(y_val, y_pred)
    RMSE_ = np.sqrt(MSE_)
    return [r_squared, MAE_, MSE_, RMSE_]

# %% [markdown]
# ### Ada Boost Regressor

# %%
def AdaBoost_Reg(X_train, y_train, X_val, y_val, depth):
    model = AdaBoostRegressor(DecisionTreeRegressor(max_depth= depth), random_state = 1)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    r_squared = model.score(X_val, y_val)
    MAE_ = metrics.mean_absolute_error(y_val, y_pred)
    MSE_ = metrics.mean_squared_error(y_val, y_pred)
    RMSE_ = np.sqrt(MSE_)
    return [r_squared, MAE_, MSE_, RMSE_]

# %% [markdown]
# ### Random Forest Regressor

# %%
def RandForest_Reg(X_train, y_train, X_val, y_val, depth):
    model = RandomForestRegressor(max_depth= depth, random_state = 1)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    r_squared = model.score(X_val, y_val)
    MAE_ = metrics.mean_absolute_error(y_val, y_pred)
    MSE_ = metrics.mean_squared_error(y_val, y_pred)
    RMSE_ = np.sqrt(MSE_)
    return [r_squared, MAE_, MSE_, RMSE_]

# %% [markdown]
# ## Training Regression Models

# %%
LR = LinReg(X_train, y_train, X_val, y_val)

#we try diffrent dgree 2,4,5 and we found that 5 is the best 
poly = Polynomial(X_train, y_train, X_val, y_val, 5) 

#we try diffrent depth, and we found that 20 is approx. the best
depth = 20
DT_Reg = DTree_Reg(X_train, y_train, X_val, y_val, depth)
AB_Reg = AdaBoost_Reg(X_train, y_train, X_val, y_val, depth)
RF_Reg = RandForest_Reg(X_train, y_train, X_val, y_val, depth)

# %%
reg_results = pd.DataFrame(data = [LR, poly, DT_Reg, AB_Reg, RF_Reg], columns=['R Squared','MAE','MSE','RMSE'],
                 index = ['Linear Regression', 'Polynomial Features', 'Decision Tree', 'Ada Boost', 'Random Forest'])

# %%
reg_results
# Out:
#                      R Squared        MAE           MSE        RMSE
# Linear Regression     0.107720  94.688636  14382.941164  119.928900
# Polynomial Features   0.421972  69.884868   9317.409699   96.526730
# Decision Tree         0.741464  44.595658   4167.416494   64.555530
# Ada Boost             0.709937  49.418598   4675.614949   68.378468
# Random Forest         0.745291  44.589948   4105.736989   64.076025

# %%
reg_results['R Squared'].max(), reg_results['MAE'].min(), reg_results['MSE'].min(), reg_results['RMSE'].min()
# Out:
# (0.745290730187959, 44.5899482670185, 4105.736988828097, 64.07602507044345)

# %%
reg_results['R Squared'].argmax(),reg_results['MAE'].argmin(),reg_results['MSE'].argmin(),reg_results['RMSE'].argmin()
# Out:
# ('Random Forest', 'Random Forest', 'Random Forest', 'Random Forest')

# %% [markdown]
# #### Now that we found that Random Forest is the best algorithm, we will call the method with `X_train_val`, `y_train_val`, `X_test`, `y_test` parameters, along with the same value of depth

# %%
RandForest_Reg_results = RandForest_Reg(X_train_val, y_train_val, X_test, y_test, depth)
print('Random Forest Regressor Results:')
print(' - R Squared:', RandForest_Reg_results[0])
print(' - MAE:', RandForest_Reg_results[1])
print(' - MSE:', RandForest_Reg_results[2])
print(' - RMSE:', RandForest_Reg_results[3])
# Out:
# Random Forest Regressor Results:
#  - R Squared: 0.7621721864713105
#  - MAE: 42.12808820816544
#  - MSE: 3584.397988693823
#  - RMSE: 59.86984206337798

# %% [markdown]
# ## Regularization

# %%
def GridSearch(model, X_train_val, y_train_val):
    kf = KFold(n_splits=5, shuffle=True, random_state=0)
    params = {"alpha": np.linspace(0, 1, num=100)}
    GS = GridSearchCV(model, param_grid=params, cv=kf)
    GS.fit(X_train_val, y_train_val);
    return GS

# %% [markdown]
# ### Lasso

# %%
def Lasso_(X_train_val, y_train_val, X_test, y_test):
    #finding the best alpha for Lasso
    Lasso_GS = GridSearch(Lasso(), X_train_val, y_train_val)
    best_alpha = Lasso_GS.best_estimator_.alpha
    
    model = Lasso(best_alpha)
    model.fit(X_train_val, y_train_val)
    
    y_pred = model.predict(X_test)
    
    r_squared = model.score(X_test, y_test)
    MAE_ = metrics.mean_absolute_error(y_test, y_pred)
    MSE_ = metrics.mean_squared_error(y_test, y_pred)
    RMSE_ = np.sqrt(MSE_)
    
    return [r_squared, MAE_, MSE_, RMSE_, best_alpha]

# %% [markdown]
# ### Ridge

# %%
def Ridge_(X_train_val, y_train_val, X_test, y_test):
    #finding the best alpha for Ridge
    Ridge_GS = GridSearch(Ridge(), X_train_val, y_train_val)
    best_alpha = Ridge_GS.best_estimator_.alpha
    
    model = Ridge(best_alpha)
    model.fit(X_train_val, y_train_val)
    
    y_pred = model.predict(X_test)
    
    r_squared = model.score(X_test, y_test)
    MAE_ = metrics.mean_absolute_error(y_test, y_pred)
    MSE_ = metrics.mean_squared_error(y_test, y_pred)
    RMSE_ = np.sqrt(MSE_)
    
    return [r_squared, MAE_, MSE_, RMSE_, best_alpha]

# %% [markdown]
# ### Elastic Net

# %%
def ElasticNet_(X_train_val, y_train_val, X_test, y_test):
    #finding the best alpha for Elastic Net
    ElasticNet_GS = GridSearch(ElasticNet(), X_train_val, y_train_val)
    best_alpha = ElasticNet_GS.best_estimator_.alpha
    
    model = ElasticNet(best_alpha)
    model.fit(X_train_val, y_train_val)
    
    y_pred = model.predict(X_test)
    
    r_squared = model.score(X_test, y_test)
    MAE_ = metrics.mean_absolute_error(y_test, y_pred)
    MSE_ = metrics.mean_squared_error(y_test, y_pred)
    RMSE_ = np.sqrt(MSE_)
    
    return [r_squared, MAE_, MSE_, RMSE_, best_alpha]

# %% [markdown]
# ## Training Regularization Models

# %%
las = Lasso_(X_train_val, y_train_val, X_test, y_test)
rid = Ridge_(X_train_val, y_train_val, X_test, y_test)
EN = ElasticNet_(X_train_val, y_train_val, X_test, y_test)

# %%
regularization_results = pd.DataFrame(data = [las, rid, EN], columns=['R Squared','MAE','MSE','RMSE','Best Alpha'],
                 index = ['Lasso', 'Ridge', 'Elastic Net'])

# %%
regularization_results
# Out:
#              R Squared        MAE           MSE        RMSE  Best Alpha
# Lasso         0.102097  92.454616  13532.658960  116.329957    0.010101
# Ridge         0.102108  92.453806  13532.488290  116.329224    1.000000
# Elastic Net   0.102110  92.453659  13532.463651  116.329118    0.000000

# %%
(regularization_results['R Squared'].max(), regularization_results['MAE'].min(), 
     regularization_results['MSE'].min(), regularization_results['RMSE'].min())
# Out:
# (0.10210968424199174,
#  92.45365900921645,
#  13532.463651407312,
#  116.32911781410237)

# %%
(regularization_results['R Squared'].argmax(), regularization_results['MAE'].argmin(), 
     regularization_results['MSE'].argmin(), regularization_results['RMSE'].argmin())
# Out:
# ('Elastic Net', 'Elastic Net', 'Elastic Net', 'Elastic Net')

# %% [markdown]
# ## Classification

# %% [markdown]
# #### Splitting the data

# %%
features = ['artist', 'level', 'venue', 'city', 'state', 'day','time', 'month', 'year', 'avg_salary']
X = df[features]
y = df.price_class

# split 80% of the data to the training set while 20% of the data to test set
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.20) 
# split 75% of the data to the training set while 25% of the data to validation set
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25)

# %% [markdown]
# ### Logistic Regression

# %%
def LogReg(X_train, y_train, X_val, y_val):
    model = LogisticRegression()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ### K Neighbors Classifier

# %%
def KNeighbors(X_train, y_train, X_val, y_val):
    model = KNeighborsClassifier()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ### Bagging Classifier

# %%
def Bagging(X_train, y_train, X_val, y_val):
    model = BaggingClassifier(KNeighborsClassifier()) 
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ### Decision Tree Classifier

# %%
def DTree_Clf(X_train, y_train, X_val, y_val, depth):
    model = DecisionTreeClassifier(max_depth= depth)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ### Ada Boost Classifier

# %%
def AdaBoost_Clf(X_train, y_train, X_val, y_val, depth):
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth= depth))
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ### Random Forest Classifier

# %%
def RandForest_Clf(X_train, y_train, X_val, y_val):
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    results =  metrics.classification_report(y_val, y_pred, target_names=['0','1'], output_dict = True)
    
    return  [results['accuracy'], results['weighted avg']['precision'], 
             results['weighted avg']['recall'], results['weighted avg']['f1-score']]

# %% [markdown]
# ## Training Classification Models

# %%
depth = 20
LogR = LogReg(X_train, y_train, X_val, y_val)
KN = KNeighbors(X_train, y_train, X_val, y_val)
bag = Bagging(X_train, y_train, X_val, y_val)
DT_Clf =  DTree_Clf(X_train, y_train, X_val, y_val, depth)
AB_Clf = AdaBoost_Clf(X_train, y_train, X_val, y_val, depth)
RF_Clf = RandForest_Clf(X_train, y_train, X_val, y_val)

# %%
clf_results = pd.DataFrame(data = [LogR, KN, bag, DT_Clf, AB_Clf, RF_Clf], columns=['Accuracy','Precision','Recall','F1'],
        index = ['Logistic Regression', 'K Neighbors', 'Bagging', 'Decision Tree ', 'Ada Boost', 'Random Forest'])

# %%
clf_results
# Out:
#                      Accuracy  Precision    Recall        F1
# Logistic Regression  0.633631   0.627439  0.633631  0.602560
# K Neighbors          0.849359   0.848851  0.849359  0.848807
# Bagging              0.859132   0.858744  0.859132  0.858819
# Decision Tree        0.863833   0.863438  0.863833  0.863353
# Ada Boost            0.864294   0.863920  0.864294  0.863967
# Random Forest        0.860791   0.860411  0.860791  0.860482

# %%
clf_results['Accuracy'].max(), clf_results['Precision'].max(), clf_results['Recall'].max(), clf_results['F1'].max()
# Out:
# (0.864294274914723, 0.8639197871876624, 0.864294274914723, 0.8639672487586659)

# %%
clf_results['Accuracy'].argmax(), clf_results['Precision'].argmax(), clf_results['Recall'].argmax(), clf_results['F1'].argmax()
# Out:
# ('Ada Boost', 'Ada Boost', 'Ada Boost', 'Ada Boost')

# %% [markdown]
# #### Now that we found that Ada Boost is the best algorithm, we will call the method with `X_train_val`, `y_train_val`, `X_test`, `y_test` parameters, along with the same value of depth

# %%
AdaBoost_Clf_results = AdaBoost_Clf(X_train_val, y_train_val, X_test, y_test, depth)
print('Ada Boost Classifier Results:')
print(' - Accuracy:', AdaBoost_Clf_results[0])
print(' - Precision:', AdaBoost_Clf_results[1])
print(' - Recall:', AdaBoost_Clf_results[2])
print(' - F1 Score:', AdaBoost_Clf_results[3])
# Out:
# Ada Boost Classifier Results:
#  - Accuracy: 0.8675209735410713
#  - Precision: 0.8672628217552432
#  - Recall: 0.8675209735410713
#  - F1 Score: 0.8673617441913546

# %% [markdown]
# # Extra for visualization in Tableau

# %%
df_cities = pd.read_csv('Cities_lng_lat.csv')
df_cities_small = df_cities[['city','state_id', 'lat', 'lng','density', 'population']]
df_cities_small.columns = ['city','state', 'lat_city', 'lng_city','density', 'population']
df_cities_small.head()
# Out:
#           city state  lat_city  lng_city  density  population
# 0     New York    NY   40.6943  -73.9249    10715    18713220
# 1  Los Angeles    CA   34.1139 -118.4068     3276    12750807
# 2      Chicago    IL   41.8373  -87.6862     4574     8604203
# 3        Miami    FL   25.7839  -80.2102     5019     6445545
# 4       Dallas    TX   32.7936  -96.7662     1526     5743938

# %%
df_states_coor = pd.read_csv('State_lng_lat.csv')
df_states_coor = df_states_coor[['state','latitude','longitude']]
df_states_coor.columns = ['state','lat_state','lng_state']
df_states_coor.head()
# Out:
#   state  lat_state   lng_state
# 0    AK  63.588753 -154.493062
# 1    AL  32.318231  -86.902298
# 2    AR  35.201050  -91.831833
# 3    AZ  34.048928 -111.093731
# 4    CA  36.778261 -119.417932

# %%
#final clean and merged dataset -> used to visualize in Tableau
df_merge = pd.merge(df_copy, df_cities_small, on=['city', 'state'])
df_new = pd.merge(df_merge, df_states_coor, on='state')

# %%
df_new.to_csv('big_data.csv', index=False)
